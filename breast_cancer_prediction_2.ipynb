# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, BatchNormalization, Dropout
from tensorflow.keras.layers import LeakyReLU, PReLU, ELU
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import plot_model

from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

# %%
df = pd.read_csv("breast_cancer.csv")

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0  ...          17.33           184.60      2019.0            0.1622
# 1  ...          23.41           158.80      1956.0            0.1238
# 2  ...          25.53           152.50      1709.0            0.1444
# 3  ...          26.50            98.87       567.7            0.2098
# 4  ...          16.67           152.20      1575.0            0.1374
#
#    compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0             0.6656           0.7119                0.2654          0.4601
# 1             0.1866           0.2416                0.1860          0.2750
# 2             0.4245           0.4504                0.2430          0.3613
# 3             0.8663           0.6869                0.2575          0.6638
# 4             0.2050           0.4000                0.1625          0.2364
#
#    fractal_dimension_worst  Unnamed: 32
# 0                  0.11890          NaN
# 1                  0.08902          NaN
# 2                  0.08758          NaN
# 3                  0.17300          NaN
# 4                  0.07678          NaN
#
# [5 rows x 33 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
#  14  perimeter_se             569 non-null    float64
#  15  area_se                  569 non-null    float64
#  16  smoothness_se            569 non-null    float64
#  17  compactness_se           569 non-null    float64
#  18  concavity_se             569 non-null    float64
#  19  concave points_se        569 non-null    float64
#  20  symmetry_se              569 non-null    float64
#  21  fractal_dimension_se     569 non-null    float64
#  22  radius_worst             569 non-null    float64
#  23  texture_worst            569 non-null    float64
#  24  perimeter_worst          569 non-null    float64
#  25  area_worst               569 non-null    float64
#  26  smoothness_worst         569 non-null    float64
#  27  compactness_worst        569 non-null    float64
#  28  concavity_worst          569 non-null    float64
#  29  concave points_worst     569 non-null    float64
#  30  symmetry_worst           569 non-null    float64
#  31  fractal_dimension_worst  569 non-null    float64
#  32  Unnamed: 32              0 non-null      float64
# dtypes: float64(31), int64(1), object(1)
# memory usage: 146.8+ KB

# %%
df.shape
# Out:
# (569, 33)

# %%
df.isna().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# symmetry_worst               0
# fractal_dimension_worst      0
# Unnamed: 32                569
# dtype: int64

# %%
df.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst', 'Unnamed: 32'],
#       dtype='object')

# %% [raw]
# *We will drop unnamed column*

# %%
df=df.drop(["Unnamed: 32","id"],axis=1)

# %%
df.shape
# Out:
# (569, 31)

# %%
print(df['diagnosis'].unique())
# Out:
# ['M' 'B']

# %% [markdown]
# # Encoding

# %%
diagnosis_mapping = {"M": 1, "B": 0}

df["diagnosis"] = df["diagnosis"].map(diagnosis_mapping)

# %% [markdown]
# # Visualization

# %%
colors = ['#FF5733', '#33FF57']

plt.figure(figsize=(10, 6))
ax = sns.countplot(x='diagnosis', data=df, palette=colors)

plt.title('Distribution of Breast Tumor Classification', fontsize=16, fontweight='bold')
plt.xlabel('Diagnosis', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.xticks([0, 1], ['Malignant', 'Benign'], fontsize=12)

for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', fontsize=12, color='black', xytext=(0, 5), textcoords='offset points')

sns.set(style="whitegrid")
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_linewidth(0.5)

plt.show()
# Out:
# D:\Archivos de Programa\envs\Tensorflow\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# D:\Archivos de Programa\envs\Tensorflow\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# D:\Archivos de Programa\envs\Tensorflow\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
correlation_matrix = df.corr()

plt.figure(figsize=(14, 10))
cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(correlation_matrix, annot=True, cmap=cmap, fmt=".2f",annot_kws={'size': 8}, linewidths=.1)

plt.title("Correlation Matrix", fontsize=16, fontweight='bold')
plt.show()

# %% [raw]
# As we can see many features are correlated to each other so we will remove highly correlated features bigger than 0.95

# %%
corr_matrix = df.corr().abs()

upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))

to_drop = [column for column in upper.columns if any(upper[column] > 0.95)]
print(to_drop)
df.drop(to_drop, axis=1, inplace=True)
# Out:
# ['perimeter_mean', 'area_mean', 'perimeter_se', 'area_se', 'radius_worst', 'perimeter_worst', 'area_worst']

# %%
len(df.columns)
# Out:
# 24

# %% [markdown]
# # Splitting Data

# %%
x=df.drop("diagnosis",axis=1)
y=df.diagnosis

# %%
y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: diagnosis, dtype: int64

# %%
x.head()
# Out:
#    radius_mean  texture_mean  smoothness_mean  compactness_mean  \
# 0        17.99         10.38          0.11840           0.27760
# 1        20.57         17.77          0.08474           0.07864
# 2        19.69         21.25          0.10960           0.15990
# 3        11.42         20.38          0.14250           0.28390
# 4        20.29         14.34          0.10030           0.13280
#
#    concavity_mean  concave points_mean  symmetry_mean  fractal_dimension_mean  \
# 0          0.3001              0.14710         0.2419                 0.07871
# 1          0.0869              0.07017         0.1812                 0.05667
# 2          0.1974              0.12790         0.2069                 0.05999
# 3          0.2414              0.10520         0.2597                 0.09744
# 4          0.1980              0.10430         0.1809                 0.05883
#
#    radius_se  texture_se  ...  concave points_se  symmetry_se  \
# 0     1.0950      0.9053  ...            0.01587      0.03003
# 1     0.5435      0.7339  ...            0.01340      0.01389
# 2     0.7456      0.7869  ...            0.02058      0.02250
# 3     0.4956      1.1560  ...            0.01867      0.05963
# 4     0.7572      0.7813  ...            0.01885      0.01756
#
#    fractal_dimension_se  texture_worst  smoothness_worst  compactness_worst  \
# 0              0.006193          17.33            0.1622             0.6656
# 1              0.003532          23.41            0.1238             0.1866
# 2              0.004571          25.53            0.1444             0.4245
# 3              0.009208          26.50            0.2098             0.8663
# 4              0.005115          16.67            0.1374             0.2050
#
#    concavity_worst  concave points_worst  symmetry_worst  \
# 0           0.7119                0.2654          0.4601
# 1           0.2416                0.1860          0.2750
# 2           0.4504                0.2430          0.3613
# 3           0.6869                0.2575          0.6638
# 4           0.4000                0.1625          0.2364
#
#    fractal_dimension_worst
# 0                  0.11890
# 1                  0.08902
# 2                  0.08758
# 3                  0.17300
# 4                  0.07678
#
# [5 rows x 23 columns]

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 23 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   radius_mean              569 non-null    float64
#  1   texture_mean             569 non-null    float64
#  2   smoothness_mean          569 non-null    float64
#  3   compactness_mean         569 non-null    float64
#  4   concavity_mean           569 non-null    float64
#  5   concave points_mean      569 non-null    float64
#  6   symmetry_mean            569 non-null    float64
#  7   fractal_dimension_mean   569 non-null    float64
#  8   radius_se                569 non-null    float64
#  9   texture_se               569 non-null    float64
#  10  smoothness_se            569 non-null    float64
#  11  compactness_se           569 non-null    float64
#  12  concavity_se             569 non-null    float64
#  13  concave points_se        569 non-null    float64
#  14  symmetry_se              569 non-null    float64
#  15  fractal_dimension_se     569 non-null    float64
#  16  texture_worst            569 non-null    float64
#  17  smoothness_worst         569 non-null    float64
#  18  compactness_worst        569 non-null    float64
#  19  concavity_worst          569 non-null    float64
#  20  concave points_worst     569 non-null    float64
#  21  symmetry_worst           569 non-null    float64
#  22  fractal_dimension_worst  569 non-null    float64
# dtypes: float64(23)
# memory usage: 102.4 KB

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=0.2,random_state=40)

# %% [markdown]
# # Scaling the Data

# %%
sc = StandardScaler()
xtrain = sc.fit_transform(xtrain)
xtest = sc.transform(xtest)

# %% [markdown]
# # Create ANN model

# %%
model = Sequential([
    Dense(30, activation="relu", name="layer1"),
    BatchNormalization(),
    Dropout(0.5),
    Dense(15, activation="relu", name="layer2"),
    BatchNormalization(),
    Dropout(0.5),
    Dense(1, activation="sigmoid", name="layer3"),
])

# %% [markdown]
# # Compiling and Fitting

# %%
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

early_stop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=25)
m=model.fit(xtrain, ytrain,batch_size = 32, validation_data=(xtest, ytest),epochs =100,callbacks = [early_stop])
# Out:
# Epoch 1/100
# 15/15 [==============================] - 2s 37ms/step - loss: 0.8859 - accuracy: 0.5758 - val_loss: 0.5770 - val_accuracy: 0.7719
# Epoch 2/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.7484 - accuracy: 0.6088 - val_loss: 0.5079 - val_accuracy: 0.8684
# Epoch 3/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.6345 - accuracy: 0.6901 - val_loss: 0.4524 - val_accuracy: 0.8860
# Epoch 4/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.5329 - accuracy: 0.7429 - val_loss: 0.4093 - val_accuracy: 0.8947
# Epoch 5/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.5015 - accuracy: 0.7824 - val_loss: 0.3754 - val_accuracy: 0.9035
# Epoch 6/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.4842 - accuracy: 0.7670 - val_loss: 0.3507 - val_accuracy: 0.9123
# Epoch 7/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.4464 - accuracy: 0.8000 - val_loss: 0.3255 - val_accuracy: 0.9035
# Epoch 8/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.4181 - accuracy: 0.8044 - val_loss: 0.3093 - val_accuracy: 0.9123
# Epoch 9/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.3855 - accuracy: 0.8396 - val_loss: 0.2913 - val_accuracy: 0.9123
# Epoch 10/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.3528 - accuracy: 0.8527 - val_loss: 0.2772 - val_accuracy: 0.9123
# Epoch 11/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.4320 - accuracy: 0.8044 - val_loss: 0.2649 - val_accuracy: 0.9123
# Epoch 12/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.3640 - accuracy: 0.8242 - val_loss: 0.2506 - val_accuracy: 0.9211
# Epoch 13/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.3657 - accuracy: 0.8571 - val_loss: 0.2405 - val_accuracy: 0.9298
# Epoch 14/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.2919 - accuracy: 0.8857 - val_loss: 0.2293 - val_accuracy: 0.9386
# Epoch 15/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.2996 - accuracy: 0.8703 - val_loss: 0.2188 - val_accuracy: 0.9386
# Epoch 16/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.2844 - accuracy: 0.8923 - val_loss: 0.2128 - val_accuracy: 0.9474
# Epoch 17/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.2545 - accuracy: 0.9187 - val_loss: 0.2044 - val_accuracy: 0.9386
# Epoch 18/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.3133 - accuracy: 0.8769 - val_loss: 0.1963 - val_accuracy: 0.9386
# Epoch 19/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.2798 - accuracy: 0.8923 - val_loss: 0.1914 - val_accuracy: 0.9386
# Epoch 20/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.2462 - accuracy: 0.9077 - val_loss: 0.1894 - val_accuracy: 0.9386
# Epoch 21/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.2625 - accuracy: 0.8857 - val_loss: 0.1848 - val_accuracy: 0.9386
# Epoch 22/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.2760 - accuracy: 0.8901 - val_loss: 0.1751 - val_accuracy: 0.9474
# Epoch 23/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.2125 - accuracy: 0.9121 - val_loss: 0.1719 - val_accuracy: 0.9386
# Epoch 24/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.2105 - accuracy: 0.9231 - val_loss: 0.1659 - val_accuracy: 0.9474
# Epoch 25/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.2530 - accuracy: 0.9143 - val_loss: 0.1629 - val_accuracy: 0.9474
# Epoch 26/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.2302 - accuracy: 0.9231 - val_loss: 0.1596 - val_accuracy: 0.9561
# Epoch 27/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.2442 - accuracy: 0.9055 - val_loss: 0.1552 - val_accuracy: 0.9561
# Epoch 28/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.2074 - accuracy: 0.9187 - val_loss: 0.1486 - val_accuracy: 0.9561
# Epoch 29/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.2147 - accuracy: 0.9231 - val_loss: 0.1436 - val_accuracy: 0.9561
# Epoch 30/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.2102 - accuracy: 0.9143 - val_loss: 0.1417 - val_accuracy: 0.9561
# Epoch 31/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.1971 - accuracy: 0.9231 - val_loss: 0.1399 - val_accuracy: 0.9561
# Epoch 32/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.2132 - accuracy: 0.9165 - val_loss: 0.1388 - val_accuracy: 0.9561
# Epoch 33/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.2299 - accuracy: 0.8967 - val_loss: 0.1371 - val_accuracy: 0.9561
# Epoch 34/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.1958 - accuracy: 0.9209 - val_loss: 0.1349 - val_accuracy: 0.9561
# Epoch 35/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.1991 - accuracy: 0.9165 - val_loss: 0.1312 - val_accuracy: 0.9561
# Epoch 36/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.1946 - accuracy: 0.9341 - val_loss: 0.1295 - val_accuracy: 0.9561
# Epoch 37/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.1693 - accuracy: 0.9451 - val_loss: 0.1286 - val_accuracy: 0.9561
# Epoch 38/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.1748 - accuracy: 0.9473 - val_loss: 0.1276 - val_accuracy: 0.9561
# Epoch 39/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.1815 - accuracy: 0.9407 - val_loss: 0.1283 - val_accuracy: 0.9561
# Epoch 40/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.1942 - accuracy: 0.9297 - val_loss: 0.1263 - val_accuracy: 0.9561
# Epoch 41/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.1525 - accuracy: 0.9516 - val_loss: 0.1267 - val_accuracy: 0.9561
# Epoch 42/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.1610 - accuracy: 0.9429 - val_loss: 0.1267 - val_accuracy: 0.9649
# Epoch 43/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.2060 - accuracy: 0.9231 - val_loss: 0.1238 - val_accuracy: 0.9649
# Epoch 44/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1759 - accuracy: 0.9319 - val_loss: 0.1213 - val_accuracy: 0.9649
# Epoch 45/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1808 - accuracy: 0.9407 - val_loss: 0.1189 - val_accuracy: 0.9649
# Epoch 46/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.2049 - accuracy: 0.9209 - val_loss: 0.1194 - val_accuracy: 0.9649
# Epoch 47/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.1497 - accuracy: 0.9473 - val_loss: 0.1193 - val_accuracy: 0.9649
# Epoch 48/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.1509 - accuracy: 0.9473 - val_loss: 0.1188 - val_accuracy: 0.9649
# Epoch 49/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.1393 - accuracy: 0.9582 - val_loss: 0.1185 - val_accuracy: 0.9649
# Epoch 50/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.1438 - accuracy: 0.9495 - val_loss: 0.1201 - val_accuracy: 0.9649
# Epoch 51/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.1502 - accuracy: 0.9407 - val_loss: 0.1202 - val_accuracy: 0.9649
# Epoch 52/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.1465 - accuracy: 0.9451 - val_loss: 0.1184 - val_accuracy: 0.9649
# Epoch 53/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.1624 - accuracy: 0.9363 - val_loss: 0.1157 - val_accuracy: 0.9649
# Epoch 54/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.1620 - accuracy: 0.9451 - val_loss: 0.1122 - val_accuracy: 0.9649
# Epoch 55/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.1200 - accuracy: 0.9626 - val_loss: 0.1111 - val_accuracy: 0.9649
# Epoch 56/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1336 - accuracy: 0.9538 - val_loss: 0.1122 - val_accuracy: 0.9649
# Epoch 57/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1496 - accuracy: 0.9516 - val_loss: 0.1155 - val_accuracy: 0.9561
# Epoch 58/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1244 - accuracy: 0.9648 - val_loss: 0.1192 - val_accuracy: 0.9561
# Epoch 59/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1337 - accuracy: 0.9516 - val_loss: 0.1182 - val_accuracy: 0.9561
# Epoch 60/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1371 - accuracy: 0.9538 - val_loss: 0.1177 - val_accuracy: 0.9561
# Epoch 61/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1463 - accuracy: 0.9385 - val_loss: 0.1194 - val_accuracy: 0.9561
# Epoch 62/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1269 - accuracy: 0.9560 - val_loss: 0.1182 - val_accuracy: 0.9561
# Epoch 63/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.1045 - accuracy: 0.9736 - val_loss: 0.1143 - val_accuracy: 0.9561
# Epoch 64/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1325 - accuracy: 0.9560 - val_loss: 0.1127 - val_accuracy: 0.9649
# Epoch 65/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.1197 - accuracy: 0.9495 - val_loss: 0.1126 - val_accuracy: 0.9649
# Epoch 66/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1290 - accuracy: 0.9451 - val_loss: 0.1116 - val_accuracy: 0.9649
# Epoch 67/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1390 - accuracy: 0.9560 - val_loss: 0.1112 - val_accuracy: 0.9649
# Epoch 68/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1397 - accuracy: 0.9560 - val_loss: 0.1125 - val_accuracy: 0.9649
# Epoch 69/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1124 - accuracy: 0.9670 - val_loss: 0.1153 - val_accuracy: 0.9561
# Epoch 70/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1287 - accuracy: 0.9538 - val_loss: 0.1145 - val_accuracy: 0.9561
# Epoch 71/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.1439 - accuracy: 0.9582 - val_loss: 0.1144 - val_accuracy: 0.9561
# Epoch 72/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1187 - accuracy: 0.9560 - val_loss: 0.1137 - val_accuracy: 0.9561
# Epoch 73/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0982 - accuracy: 0.9758 - val_loss: 0.1149 - val_accuracy: 0.9561
# Epoch 74/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.1208 - accuracy: 0.9516 - val_loss: 0.1106 - val_accuracy: 0.9561
# Epoch 75/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.1616 - accuracy: 0.9385 - val_loss: 0.1129 - val_accuracy: 0.9561
# Epoch 76/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.1165 - accuracy: 0.9604 - val_loss: 0.1132 - val_accuracy: 0.9561
# Epoch 77/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.1182 - accuracy: 0.9626 - val_loss: 0.1137 - val_accuracy: 0.9561
# Epoch 78/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.1250 - accuracy: 0.9495 - val_loss: 0.1149 - val_accuracy: 0.9561
# Epoch 79/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.1278 - accuracy: 0.9429 - val_loss: 0.1077 - val_accuracy: 0.9561
# Epoch 80/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.1278 - accuracy: 0.9582 - val_loss: 0.1091 - val_accuracy: 0.9561
# Epoch 81/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0944 - accuracy: 0.9648 - val_loss: 0.1095 - val_accuracy: 0.9561
# Epoch 82/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.1077 - accuracy: 0.9538 - val_loss: 0.1083 - val_accuracy: 0.9561
# Epoch 83/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.1100 - accuracy: 0.9626 - val_loss: 0.1095 - val_accuracy: 0.9561
# Epoch 84/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.1143 - accuracy: 0.9582 - val_loss: 0.1108 - val_accuracy: 0.9561
# Epoch 85/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.1192 - accuracy: 0.9582 - val_loss: 0.1102 - val_accuracy: 0.9561
# Epoch 86/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0885 - accuracy: 0.9736 - val_loss: 0.1083 - val_accuracy: 0.9649
# Epoch 87/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.1069 - accuracy: 0.9604 - val_loss: 0.1077 - val_accuracy: 0.9649
# Epoch 88/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.1478 - accuracy: 0.9516 - val_loss: 0.1068 - val_accuracy: 0.9561
# Epoch 89/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0920 - accuracy: 0.9692 - val_loss: 0.0990 - val_accuracy: 0.9649
# Epoch 90/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.1230 - accuracy: 0.9538 - val_loss: 0.0983 - val_accuracy: 0.9649
# Epoch 91/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0954 - accuracy: 0.9714 - val_loss: 0.1007 - val_accuracy: 0.9649
# Epoch 92/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1396 - accuracy: 0.9516 - val_loss: 0.0984 - val_accuracy: 0.9649
# Epoch 93/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1533 - accuracy: 0.9516 - val_loss: 0.0974 - val_accuracy: 0.9649
# Epoch 94/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.1217 - accuracy: 0.9538 - val_loss: 0.0954 - val_accuracy: 0.9649
# Epoch 95/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0996 - accuracy: 0.9670 - val_loss: 0.0953 - val_accuracy: 0.9649
# Epoch 96/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.1138 - accuracy: 0.9626 - val_loss: 0.0927 - val_accuracy: 0.9649
# Epoch 97/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.1265 - accuracy: 0.9648 - val_loss: 0.0944 - val_accuracy: 0.9649
# Epoch 98/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.1197 - accuracy: 0.9626 - val_loss: 0.0972 - val_accuracy: 0.9561
# Epoch 99/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.1462 - accuracy: 0.9560 - val_loss: 0.0970 - val_accuracy: 0.9561
# Epoch 100/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.1065 - accuracy: 0.9604 - val_loss: 0.0978 - val_accuracy: 0.9561

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  layer1 (Dense)              (None, 30)                720
#
#  batch_normalization (BatchN  (None, 30)               120
#  ormalization)
#
#  dropout (Dropout)           (None, 30)                0
#
#  layer2 (Dense)              (None, 15)                465
#
#  batch_normalization_1 (Batc  (None, 15)               60
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 15)                0
#
#  layer3 (Dense)              (None, 1)                 16
#
# =================================================================
# Total params: 1,381
# Trainable params: 1,291
# Non-trainable params: 90
# _________________________________________________________________

# %%
losses = pd.DataFrame(model.history.history)
losses.plot()
# Out:
# <Axes: >

# %%
y_pred = model.predict(xtest)
y_pred = (y_pred>0.5)
# Out:
# 4/4 [==============================] - 0s 5ms/step

# %%
cm = confusion_matrix(ytest,y_pred)
score = accuracy_score(ytest,y_pred)
print(cm)
print('score is:',score)
# Out:
# [[72  3]
#  [ 2 37]]
# score is: 0.956140350877193

# %%
print(classification_report(ytest,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.97        75
#            1       0.93      0.95      0.94        39
#
#     accuracy                           0.96       114
#    macro avg       0.95      0.95      0.95       114
# weighted avg       0.96      0.96      0.96       114

# %%
plt.figure(figsize=[14,7])
sns.heatmap(cm,annot=True)
plt.show()

# %%
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
model.save('breast_cancer_prediction_model.h5')
